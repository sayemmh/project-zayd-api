# %%
import pandas as pd
import ujson
import json
import constants

prefix = '../output-data/json-surah-words/'

i = 114

surah_df = pd.read_json(prefix + str(i) + '.json')

# %%
surah_df
# Out:
#                    answer                                arabicAyah  ayahnum  \
# 0             The one who   الَّذِي يُوَسْوِسُ فِي صُدُورِ النَّاسِ        5
# 1               (The) God                          إِلَٰهِ النَّاسِ        3
# 2                the jinn                مِنَ الْجِنَّةِ وَالنَّاسِ        6
# 3   the one who withdraws       مِنْ شَرِّ الْوَسْوَاسِ الْخَنَّاسِ        4
# 4           in (the) Lord             قُلْ أَعُوذُ بِرَبِّ النَّاسِ        1
# 5              (the) evil       مِنْ شَرِّ الْوَسْوَاسِ الْخَنَّاسِ        4
# 6           (the) breasts   الَّذِي يُوَسْوِسُ فِي صُدُورِ النَّاسِ        5
# 7           I seek refuge             قُلْ أَعُوذُ بِرَبِّ النَّاسِ        1
# 8                     Say             قُلْ أَعُوذُ بِرَبِّ النَّاسِ        1
# 9              (The) King                           مَلِكِ النَّاسِ        2
# 10           (of) mankind             قُلْ أَعُوذُ بِرَبِّ النَّاسِ        1
# ...
