# %%
import numpy as np
import pandas as pd
import pickle as pckl
import math

# %% [markdown]
# todo: make function where you can input a list of ayahs and it will
# return the corresponding root words and words-in-context of those ayahs

# %%
fh = open("ranked_ayahs.pckl","rb")
df = pckl.load(fh)
fh.close()
# df = df.sort_values(by=name_of_col, ascending=False)

# df['rounded85th'] = df.loc[:, '85th_perc'].apply(lambda x: int(math.ceil(x / 250.0)) * 250)
# df['rounded85th'].hist(bins=100)

# %%
df2 = df.copy(deep=True)

# different ranking methods
# df2['easiness'] = df2['rounded85th'] + df2['15th_perc'] + df2['min_freq_score']
df2['easiness'] = df2['85th_perc'] + 2 * df2['15th_perc'] + df2['min_freq_score']

df2 = df2.sort_values(by='easiness', ascending=False)
df2.head(10)
# Out:
#      surahayahnum  mean_freq_score  min_freq_score  level  num_words_in_ayah  \
# 3819        44/34      3627.742574     3627.742574  426.0                  1
# 3071       37/167      3247.003588     2866.264602  444.0                  2
# 1443        20/49      2789.576640     1951.410706  466.0                  2
# 1791        23/85      3521.854378      515.135093  192.0                  4
# 1793        23/87      3505.459056      449.553804  192.0                  4
# 3100        37/29      2741.789568     1731.361526  462.0                  3
# 325         114/3      3366.938339      417.079406  140.0                  2
# 5479        76/30      2593.099350      358.460432   27.0                  8
# 2532          3/2      3095.284106      309.955684    0.0                  5
# 4864        64/13      3676.400436      107.055219    0.0                  6
#
#         85th_perc    15th_perc      easiness
# 3819  3627.742574  3627.742574  14510.970298
# 3071  3513.520879  2980.486298  12340.758077
# 1443  3376.292794  2202.860486   9733.424472
# 1791  5106.722658  1915.808460   9453.474670
# 1793  5106.722658  1879.738750   9315.753962
# 3100  3399.299183  2071.832449   9274.325608
# 325   5431.839591  1302.037086   8452.993170
# 5479  6144.270638   969.804274   8442.339617
# 2532  6316.797271   881.948020   8390.648995
# 4864  6316.797271   978.959348   8381.771187

# %%
df3 = df2.head(20).copy(deep=True)
cur_level = list(df3['surahayahnum'])
cur_level
# Out:
# ['44/34',
#  '37/167',
#  '20/49',
#  '23/85',
#  '23/87',
#  '37/29',
#  '114/3',
#  '76/30',
#  '3/2',
#  '64/13',
#  '26/23',
#  '8/33',
#  '112/1',
#  '43/84',
#  '37/35',
#  '7/121',
#  '26/47',
#  '15/96',
#  '24/18',
#  '49/16']

# %%
# fh = open("surah_df.pckl","rb")
# surah_df = pckl.load(fh)
# fh.close()

# %%
level_df = surah_df[surah_df['surahayahnum'].isin(cur_level)]
level_df
# Out:
#                                  answer  \
# 4374                             except
# 4466                                God
# 4471                             Allah
# 5159                    the Ever-Living
# 6099   the Sustainer of all that exists
# 13769                        We believe
# 14311                     in (the) Lord
# 14801                   (of) the worlds
# 15074                         They said
# 15794                       (for) Allah
# 15795                             Allah
# 16207             that He punishes them
# 16214         the One Who punishes them
# 16276                  seek forgiveness
# 16404                                is
# 16405                                is
# 23227                           another
# 23254                         Those who
# 23256                               god
# 23258                             Allah
# 23319                            set up
# 23481            they will come to know
# 28226                    (is) your Lord
# 28541                           He said
# 30533                          To Allah
# 30534                             Allah
# 30711                      you remember
# 30949                     They will say
# 30950                               Say
# 30952                     They will say
# ...                                 ...
# 46137                             Allah
# 46138                       while Allah
# 46139                         And Allah
# 46203                with your religion
# 46225                       the heavens
# 46230                             thing
# 46257                             knows
# 46259                 Will you acquaint
# 46263                   (is) All-Knower
# 46296                               Say
# 46309                          of every
# 49810                            except
# 49818                               god
# 49832                             Allah
# 49833                             Allah
# 49846                     the believers
# 49972             let put (their) trust
# 51947                            except
# 51952                             Allah
# 51953                             Allah
# 51978                          All-Wise
# 52034                          you will
# 52035                             wills
# 52057                        All-Knower
# 52089                                is
# 53880                           the One
# 53882                        (is) Allah
# 53885                               Say
# 53908                         (The) God
# 53919                      (of) mankind
#
#                                               arabicAyah  ayahnum  frequency  \
# 4374    اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ الْحَيُّ الْق...        2        663
# 4466    اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ الْحَيُّ الْق...        2       2851
# 4471    اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ الْحَيُّ الْق...        2       2851
# 5159    اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ الْحَيُّ الْق...        2        184
# 6099    اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ الْحَيُّ الْق...        2        660
# 13769              قَالُوا آمَنَّا بِرَبِّ الْعَالَمِينَ      121        879
# 14311              قَالُوا آمَنَّا بِرَبِّ الْعَالَمِينَ      121        980
# 14801              قَالُوا آمَنَّا بِرَبِّ الْعَالَمِينَ      121        854
# 15074              قَالُوا آمَنَّا بِرَبِّ الْعَالَمِينَ      121       1722
# 15794   وَمَا كَانَ اللَّهُ لِيُعَذِّبَهُمْ وَأَنْتَ ...       33       2851
# 15795   وَمَا كَانَ اللَّهُ مُعَذِّبَهُمْ وَهُمْ يَسْ...       33       2851
# 16207   وَمَا كَانَ اللَّهُ لِيُعَذِّبَهُمْ وَأَنْتَ ...       33        373
# 16214   وَمَا كَانَ اللَّهُ مُعَذِّبَهُمْ وَهُمْ يَسْ...       33        373
# 16276   وَمَا كَانَ اللَّهُ لِيُعَذِّبَهُمْ وَأَنْتَ ...       33        234
# 16404   وَمَا كَانَ اللَّهُ لِيُعَذِّبَهُمْ وَأَنْتَ ...       33       1390
# 16405   وَمَا كَانَ اللَّهُ مُعَذِّبَهُمْ وَهُمْ يَسْ...       33       1390
# 23227   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96        250
# 23254   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96       1464
# 23256   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96       2851
# 23258   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96       2851
# 23319   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96        346
# 23481   الَّذِينَ يَجْعَلُونَ مَعَ اللَّهِ إِلَٰهًا آ...       96        854
# 28226                قَالَ فَمَنْ رَبُّكُمَا يَا مُوسَىٰ       49        980
# 28541                قَالَ فَمَنْ رَبُّكُمَا يَا مُوسَىٰ       49       1722
# 30533     سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَذَكَّرُونَ       85       2851
# 30534       سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَتَّقُونَ       87       2851
# 30711     سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَذَكَّرُونَ       85        292
# 30949     سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَذَكَّرُونَ       85       1722
# 30950     سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَذَكَّرُونَ       85       1722
# 30952       سَيَقُولُونَ لِلَّهِ قُلْ أَفَلَا تَتَّقُونَ       87       1722
# ...                                                  ...      ...        ...
# 46137   قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ وَالل...       16       2851
# 46138   قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ وَالل...       16       2851
# 46139                   وَاللَّهُ بِكُلِّ شَيْءٍ عَلِيمٌ       16       2851
# 46203   قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ وَالل...       16        101
# 46225   قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ وَالل...       16        381
# 46230   وَاللَّهُ يَعْلَمُ مَا فِي السَّمَاوَاتِ وَمَ...       16        519
# 46257   وَاللَّهُ يَعْلَمُ مَا فِي السَّمَاوَاتِ وَمَ...       16        854
# 46259   قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ وَالل...       16        854
# 46263   وَاللَّهُ يَعْلَمُ مَا فِي السَّمَاوَاتِ وَمَ...       16        854
# 46296            قُلْ أَتُعَلِّمُونَ اللَّهَ بِدِينِكُمْ       16       1722
# 46309   وَاللَّهُ يَعْلَمُ مَا فِي السَّمَاوَاتِ وَمَ...       16        377
# 49810   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13        663
# 49818   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13       2851
# 49832   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13       2851
# 49833   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13       2851
# 49846   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13        879
# 49972   اللَّهُ لَا إِلَٰهَ إِلَّا هُوَ وَعَلَى اللَّ...       13         70
# 51947       وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ       30        663
# 51952   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30       2851
# 51953   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30       2851
# 51978   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30        210
# 52034       وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ       30        519
# 52035   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30        519
# 52057   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30        854
# 52089   وَمَا تَشَاءُونَ إِلَّا أَنْ يَشَاءَ اللَّهُ ...       30       1390
# 53880                           قُلْ هُوَ اللَّهُ أَحَدٌ        1         85
# 53882                           قُلْ هُوَ اللَّهُ أَحَدٌ        1       2851
# 53885                           قُلْ هُوَ اللَّهُ أَحَدٌ        1       1722
# 53908                                   إِلَٰهِ النَّاسِ        3       2851
# 53919                                   إِلَٰهِ النَّاسِ        3        241
#
#        pcklId         question rootWord  rootWordId     rootWordType  \
# 4374      579           إِلَّا   إِلَّا          58         particle
# 4466        7          إِلَٰهَ    أ ل ه          61  triliteral root
# 4471      431          اللَّهُ    أ ل ه          61  triliteral root
# 5159       73         الْحَيُّ    ح ي ي         381  triliteral root
# 6099      567      الْقَيُّومُ    ق و م        1246  triliteral root
# 13769     219          آمَنَّا    أ م ن          75  triliteral root
# 14311     200          بِرَبِّ    ر ب ب         524  triliteral root
# 14801     499    الْعَالَمِينَ    ع ل م        1016  triliteral root
# 15074     448          قَالُوا    ق و ل        1245  triliteral root
# 15794    1194          اللَّهُ    أ ل ه          61  triliteral root
# 15795    1195          اللَّهُ    أ ل ه          61  triliteral root
# 16207      11  لِيُعَذِّبَهُمْ    ع ذ ب         968  triliteral root
# 16214     366    مُعَذِّبَهُمْ    ع ذ ب         968  triliteral root
# 16276      73  يَسْتَغْفِرُونَ    غ ف ر        1071  triliteral root
# 16404     416            كَانَ    ك و ن        1305  triliteral root
# 16405     417            كَانَ    ك و ن        1305  triliteral root
# 23227     230            آخَرَ    أ خ ر          22  triliteral root
# 23254     651        الَّذِينَ  ٱلَّذِى          59          nominal
# 23256      45         إِلَٰهًا    أ ل ه          61  triliteral root
# 23258    1636          اللَّهِ    أ ل ه          61  triliteral root
# 23319     101      يَجْعَلُونَ    ج ع ل         249  triliteral root
# 23481     189      يَعْلَمُونَ    ع ل م        1016  triliteral root
# 28226     484       رَبُّكُمَا    ر ب ب         524  triliteral root
# 28541     912            قَالَ    ق و ل        1245  triliteral root
# 30533    1848          لِلَّهِ    أ ل ه          61  triliteral root
# 30534    1849          لِلَّهِ    أ ل ه          61  triliteral root
# 30711     126     تَذَكَّرُونَ    ذ ك ر         511  triliteral root
# 30949    1000     سَيَقُولُونَ    ق و ل        1245  triliteral root
# 30950    1001             قُلْ    ق و ل        1245  triliteral root
# 30952    1003     سَيَقُولُونَ    ق و ل        1245  triliteral root
# ...       ...              ...      ...         ...              ...
# 46137    2546          اللَّهَ    أ ل ه          61  triliteral root
# 46138    2547        وَاللَّهُ    أ ل ه          61  triliteral root
# 46139    2548        وَاللَّهُ    أ ل ه          61  triliteral root
# 46203      72      بِدِينِكُمْ    د ي ن         498  triliteral root
# 46225     298    السَّمَاوَاتِ    س م و         726  triliteral root
# 46230     479           شَيْءٍ    ش ي أ         810  triliteral root
# 46257     331         يَعْلَمُ    ع ل م        1016  triliteral root
# 46259     416   أَتُعَلِّمُونَ    ع ل م        1016  triliteral root
# 46263     755          عَلِيمٌ    ع ل م        1016  triliteral root
# 46296    1487             قُلْ    ق و ل        1245  triliteral root
# 46309     312          بِكُلِّ    ك ل ل        1288  triliteral root
# 49810     641           إِلَّا   إِلَّا          58         particle
# 49818     143          إِلَٰهَ    أ ل ه          61  triliteral root
# 49832    2743          اللَّهُ    أ ل ه          61  triliteral root
# 49833    2744          اللَّهِ    أ ل ه          61  triliteral root
# 49846     837   الْمُؤْمِنُونَ    أ م ن          75  triliteral root
# 49972      39  فَلْيَتَوَكَّلِ    و ك ل        1645  triliteral root
# 51947     550           إِلَّا   إِلَّا          58         particle
# 51952    2823          اللَّهُ    أ ل ه          61  triliteral root
# 51953    2824          اللَّهَ    أ ل ه          61  triliteral root
# 51978     201         حَكِيمًا    ح ك م         345  triliteral root
# 52034     225       تَشَاءُونَ    ش ي أ         810  triliteral root
# 52035     226          يَشَاءَ    ش ي أ         810  triliteral root
# 52057     821         عَلِيمًا    ع ل م        1016  triliteral root
# 52089    1334            كَانَ    ك و ن        1305  triliteral root
# 53880      72           أَحَدٌ    أ ح د          20  triliteral root
# 53882    2844          اللَّهُ    أ ل ه          61  triliteral root
# 53885    1615             قُلْ    ق و ل        1245  triliteral root
# 53908     146          إِلَٰهِ    أ ل ه          61  triliteral root
# 53919     238         النَّاسِ    ن و س        1530  triliteral root
#
#        surahnum            tlit         wazn            waznEnglish  \
# 4374          3            illā       إِلَّا                 except
# 4466          3           ilāha       إِلَٰه                    god
# 4471          3         al-lahu       ٱللَّه                  Allah
# 5159          3          l-ḥayu         حَيّ          you will live
# 6099          3        l-qayūmu      قَيُّوم     they stand (still)
# 13769         7          āmannā      ءَامَنَ             to believe
# 14311         7         birabbi         رَبّ               the Lord
# 14801         7      l-ʿālamīna    عَٰلَمِين              they know
# 15074         7            qālū        قَالَ                 to say
# 15794         8          l-lahu       ٱللَّه                  Allah
# 15795         8          l-lahu       ٱللَّه                  Allah
# 16207         8  liyuʿadhibahum      عَذَّبَ              to punish
# 16214         8    muʿadhibahum     مُعَذِّب     and He will punish
# 16276         8   yastaghfirūna  ٱسْتَغْفَرَ     to ask forgiveness
# 16404         8            kāna        كَانَ                  to be
# 16405         8            kāna        كَانَ                  to be
# 23227        15          ākhara         آخَر            other, last
# 23254        15       alladhīna      ٱلَّذِى       who, which, that
# 23256        15          ilāhan       إِلَٰه                    god
# 23258        15          l-lahi       ٱللَّه                  Allah
# 23319        15       yajʿalūna       جَعَلَ                to make
# 23481        15       yaʿlamūna       عَلِمَ                to know
# 28226        20       rabbukumā         رَبّ               the Lord
# 28541        20            qāla        قَالَ                 to say
# 30533        23         lillahi       ٱللَّه                  Allah
# 30534        23         lillahi       ٱللَّه                  Allah
# 30711        23    tadhakkarūna    تَذَكَّرَ  to receive admonition
# 30949        23      sayaqūlūna        قَالَ                 to say
# 30950        23             qul        قَالَ                 to say
# 30952        23      sayaqūlūna        قَالَ                 to say
# ...         ...             ...          ...                    ...
# 46137        49          l-laha       ٱللَّه                  Allah
# 46138        49        wal-lahu       ٱللَّه                  Allah
# 46139        49        wal-lahu       ٱللَّه                  Allah
# 46203        49       bidīnikum         دِين       they acknowledge
# 46225        49      l-samāwāti       سَمَآء   [I] (have) named her
# 46230        49          shayin        شَىْء             had willed
# 46257        49         yaʿlamu       عَلِمَ                to know
# 46259        49    atuʿallimūna      عَلَّمَ               to teach
# 46263        49         ʿalīmun       عَلِيم              they know
# 46296        49             qul        قَالَ                 to say
# 46309        49         bikulli         كُلّ          (is) a burden
# 49810        64            illā       إِلَّا                 except
# 49818        64           ilāha       إِلَٰه                    god
# 49832        64         al-lahu       ٱللَّه                  Allah
# 49833        64          l-lahi       ٱللَّه                  Allah
# 49846        64     l-mu'minūna      مُؤْمِن         you are secure
# 49972        64  falyatawakkali    تَوَكَّلْ           to put trust
# 51947        76            illā       إِلَّا                 except
# 51952        76          l-lahu       ٱللَّه                  Allah
# 51953        76          l-laha       ٱللَّه                  Allah
# 51978        76         ḥakīman       حَكِيم             will judge
# 52034        76        tashāūna        شَآءَ       to will, to wish
# 52035        76          yashāa        شَآءَ       to will, to wish
# 52057        76         ʿalīman       عَلِيم              they know
# 52089        76            kāna        كَانَ                  to be
# 53880       112          aḥadun        أَحَد            one, anyone
# 53882       112          l-lahu       ٱللَّه                  Allah
# 53885       112             qul        قَالَ                 to say
# 53908       114           ilāhi       إِلَٰه                    god
# 53919       114          l-nāsi        ن و س             the people
#
#           waznTlit                            waznType  wordnum surahayahnum
# 4374          illā       Particle (Exceptive particle)        4          3/2
# 4466          ilāh                                Noun        3          3/2
# 4471         allah                         Proper noun        1          3/2
# 5159          ḥayy                      Nominal (Noun)        6          3/2
# 6099        qayyūm                           Adjective        7          3/2
# 13769        āmana                      Verb (form IV)        2        7/121
# 14311         rabb                                Noun        3        7/121
# 14801      ʿālamīn                                Noun        4        7/121
# 15074         qāla                       Verb (form I)        1        7/121
# 15794        allah                         Proper noun        3         8/33
# 15795        allah                         Proper noun        9         8/33
# 16207      ʿadhaba                      Verb (form II)        4         8/33
# 16214     muʿadhib         Active participle (form II)       10         8/33
# 16276  is'taghfara                       Verb (form X)       12         8/33
# 16404         kāna                       Verb (form I)        2         8/33
# 16405         kāna                       Verb (form I)        8         8/33
# 23227        ākhar                 Nominal (Adjective)        6        15/96
# 23254      alladhī          Nominal (Relative pronoun)        1        15/96
# 23256         ilāh                                Noun        5        15/96
# 23258        allah                         Proper noun        4        15/96
# 23319       jaʿala                       Verb (form I)        2        15/96
# 23481       ʿalima                       Verb (form I)        8        15/96
# 28226         rabb                                Noun        3        20/49
# 28541         qāla                       Verb (form I)        1        20/49
# 30533        allah                         Proper noun        2        23/85
# 30534        allah                         Proper noun        2        23/87
# 30711   tadhakkara                       Verb (form V)        5        23/85
# 30949         qāla                       Verb (form I)        1        23/85
# 30950         qāla                       Verb (form I)        3        23/85
# 30952         qāla                       Verb (form I)        1        23/87
# ...            ...                                 ...      ...          ...
# 46137        allah                         Proper noun        3        49/16
# 46138        allah                         Proper noun        5        49/16
# 46139        allah                         Proper noun       13        49/16
# 46203          dīn                                Noun        4        49/16
# 46225         samā                                Noun        9        49/16
# 46230         shay                                Noun       15        49/16
# 46257       ʿalima                       Verb (form I)        6        49/16
# 46259      ʿallama                      Verb (form II)        2        49/16
# 46263        ʿalīm                 Nominal (Adjective)       16        49/16
# 46296         qāla                       Verb (form I)        1        49/16
# 46309         kull                      Nominal (Noun)       14        49/16
# 49810         illā       Particle (Exceptive particle)        4        64/13
# 49818         ilāh                                Noun        3        64/13
# 49832        allah                         Proper noun        1        64/13
# 49833        allah                         Proper noun        7        64/13
# 49846       mu'min  Active participle (form IV) (Noun)        9        64/13
# 49972     tawakkal                       Verb (form V)        8        64/13
# 51947         illā     Particle (Restriction particle)        3        76/30
# 51952        allah                         Proper noun        6        76/30
# 51953        allah                         Proper noun        8        76/30
# 51978        ḥakīm                      Nominal (Noun)       11        76/30
# 52034         shāa                       Verb (form I)        2        76/30
# 52035         shāa                       Verb (form I)        5        76/30
# 52057        ʿalīm                      Nominal (Noun)       10        76/30
# 52089         kāna                       Verb (form I)        9        76/30
# 53880         aḥad                                Noun        4        112/1
# 53882        allah                         Proper noun        3        112/1
# 53885         qāla                       Verb (form I)        1        112/1
# 53908         ilāh                                Noun        1        114/3
# 53919  nūn wāw sīn                                Noun        2        114/3
#
# [96 rows x 17 columns]

# %%
# don't know how many root-word-forms are in here bc don't have the data yet, but need to
# calculate unique # of root words in this level and what's a reasonable # of words per level

# do we need a similarity matrix now?
# we need to better optimize ratio of words / ayahs
numwords = len(set(level_df['rootWordId']))
numayahs = len(cur_level)
print("Number of ayahs in level: " + str(numayahs))
print("Number of words in level: " + str(numwords))
print("ratio: " + str(numwords / numayahs))
# Out:
# Number of ayahs in level: 20
# Number of words in level: 29
# ratio: 1.45

# %%
import hashlib
output = level_df.copy(deep=True)
output['question_id'] = level_df['surahnum'].astype(str)  + '-' + level_df['ayahnum'].astype(str) + '-' + level_df['wordnum'].astype(str)
output = output['question_id']
output = [int(hashlib.sha256(s.encode('utf-8')).hexdigest(), 16) % 10**8 for s in output]

# %%
import ujson
levels = {1: list(output)}
with open("levels.json", 'w') as f:
    ujson.dump(levels, f)

# %%
# !pwd
# Out:
# /Users/sayemhoque/Documents/project-zayd-data
